# %% [markdown]
# # Studio 1 — Data ER: PPP loans in Connecticut 🏥📊
#
# **OPIM 5641 · Business Decision Modeling · Dr. Dave Wanik, UConn**
#
# The SBA's Paycheck Protection Program made ~11.5 million emergency loans in 2020–21, and the
# loan-level data is public. This is **real data, warts and all** — missing codes, "Unanswered"
# fields, suspicious job counts. Tonight we do a **Data ER**: triage first, diagnose second,
# and finish with **three findings** you can defend.
#
# *When you have data, explore it. (Next notebook: when you don't, simulate it.)*
#
# > **The GitHub habit (do this now):** File → **Save a copy in GitHub** → pick your `opim5641-work` repo.
# > Do it again at the end of the night. Open from the course repo, work, save to *your* repo — that's the loop.

# %% [markdown]
# ## 1 · Load the data
#
# One CSV, already filtered to Connecticut. Every column the SBA publishes is intact — including the messy ones.
#
# > 📖 **What do all 53 columns mean?** See the [data dictionary](https://github.com/drdave-teaching/OPIM5641-notebooks/blob/main/studio1/ppp_data_dictionary.md) — official SBA descriptions plus the watch-outs (which columns lie, which are mostly “Unanswered”, and why missing ≠ zero).

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

url = 'https://raw.githubusercontent.com/drdave-teaching/OPIM5641-notebooks/main/studio1/ppp_ct.csv'
df = pd.read_csv(url, low_memory=False)
print(df.shape)
df.head(3)
# Out:
# (117888, 53)
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  3903327306   04/29/2020            156              PPP
# 1  4505207402   05/09/2020            156              PPP
# 2  5539227705   05/01/2020            156              PPP
#
#                    BorrowerName           BorrowerAddress BorrowerCity  \
# 0                   PROPARK INC             1 Union Place     Hartford
# 1  MONROE STAFFING SERVICES LLC             6 RESEARCH DR      SHELTON
# 2      CENVEO WORLDWIDE LIMITED  200 First Stamford Place     Stamford
#
#   BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0            CT       06103     08/12/2022  Paid in Full    60
# 1            CT  06484-6228     06/22/2021  Paid in Full    24
# 2            CT       06902     07/16/2021  Paid in Full    24
#
#    SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 0                    100             10000000.0             10000000.0
# 1                    100             10000000.0             10000000.0
# 2                    100             10000000.0             10000000.0
#
#    UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 0                0.0           NaN                     434162
# 1                0.0           NaN                      81965
# 2                0.0           NaN                       9551
#
#                      ServicingLenderName   ServicingLenderAddress  \
# 0    Citizens Bank, National Association         1 Citizens Plaza
# 1    Affinity Bank, National Association             3175 Hwy 278
# 2  Bank of America, National Association  100 N Tryon St, Ste 170
#
#   ServicingLenderCity ServicingLenderState ServicingLenderZip  \
# 0          PROVIDENCE                   RI         02903-1344
# 1           Covington                   GA              30014
# 2           CHARLOTTE                   NC         28202-4024
#
#   RuralUrbanIndicator HubzoneIndicator LMIIndicator  \
# 0                   U                N            Y
# 1                   U                N            N
# 2                   U                Y            Y
#
#               BusinessAgeDescription ProjectCity ProjectCountyName  \
# 0  Existing or more than 2 years old    Hartford          HARTFORD
# 1                         Unanswered     SHELTON         FAIRFIELD
# 2    New Business or 2 years or less    Stamford         FAIRFIELD
#
#   ProjectState  ProjectZip     CD  JobsReported  NAICSCode        Race  \
# 0           CT  06103-1000  CT-01           500   812930.0  Unanswered
# 1           CT  06484-6228  CT-03           500   561311.0  Unanswered
# 2           CT  06902-0001  CT-04           500   322230.0  Unanswered
#
#            Ethnicity  UTILITIES_PROCEED  PAYROLL_PROCEED  \
# 0  Unknown/NotStated                NaN       10000000.0
# 1  Unknown/NotStated                NaN       10000000.0
# 2  Unknown/NotStated                NaN       10000000.0
#
#    MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  REFINANCE_EIDL_PROCEED  \
# 0                        NaN           NaN                     NaN
# 1                        NaN           NaN                     NaN
# 2                        NaN           NaN                     NaN
#
#    HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED BusinessType  \
# 0                  NaN                    NaN  Corporation
# 1                  NaN                    NaN  Corporation
# 2                  NaN                    NaN  Corporation
#
#    OriginatingLenderLocationID                      OriginatingLender  \
# 0                       434162    Citizens Bank, National Association
# 1                        81965    Affinity Bank, National Association
# 2                         9551  Bank of America, National Association
#
#   OriginatingLenderCity OriginatingLenderState      Gender     Veteran  \
# 0            PROVIDENCE                     RI  Unanswered  Unanswered
# 1             Covington                     GA  Unanswered  Unanswered
# 2             CHARLOTTE                     NC  Unanswered  Unanswered
#
#   NonProfit  ForgivenessAmount ForgivenessDate
# 0       NaN        10223013.70      07/28/2022
# 1       NaN        10104722.22      05/25/2021
# 2       NaN        10110410.96      06/11/2021

# %% [markdown]
# ## 2 · Triage: what have we got?
#
# Before any analysis: how many rows and columns, what types, and **where are the holes**?

# %%
df.shape# YOUR CODE HERE 🛠️  (we build this together in studio)\n
# Out:
# (117888, 53)

# %%
#Check the missing number of values, check for not-null gap
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117888 entries, 0 to 117887
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   117888 non-null  int64
#  1   DateApproved                 117888 non-null  object
#  2   SBAOfficeCode                117888 non-null  int64
#  3   ProcessingMethod             117888 non-null  object
#  4   BorrowerName                 117888 non-null  object
#  5   BorrowerAddress              117888 non-null  object
#  6   BorrowerCity                 117888 non-null  object
#  7   BorrowerState                117888 non-null  object
#  8   BorrowerZip                  117888 non-null  object
#  9   LoanStatusDate               116775 non-null  object
#  10  LoanStatus                   117888 non-null  object
#  11  Term                         117888 non-null  int64
#  12  SBAGuarantyPercentage        117888 non-null  int64
#  13  InitialApprovalAmount        117888 non-null  float64
#  14  CurrentApprovalAmount        117888 non-null  float64
#  15  UndisbursedAmount            117885 non-null  float64
#  16  FranchiseName                1694 non-null    object
#  17  ServicingLenderLocationID    117888 non-null  int64
#  18  ServicingLenderName          117888 non-null  object
#  19  ServicingLenderAddress       117888 non-null  object
#  20  ServicingLenderCity          117888 non-null  object
#  21  ServicingLenderState         117888 non-null  object
#  22  ServicingLenderZip           117888 non-null  object
#  23  RuralUrbanIndicator          117888 non-null  object
#  24  HubzoneIndicator             117888 non-null  object
#  25  LMIIndicator                 117887 non-null  object
#  26  BusinessAgeDescription       117888 non-null  object
#  27  ProjectCity                  117888 non-null  object
#  28  ProjectCountyName            117868 non-null  object
#  29  ProjectState                 117888 non-null  object
#  30  ProjectZip                   117888 non-null  object
#  31  CD                           117877 non-null  object
#  32  JobsReported                 117888 non-null  int64
#  33  NAICSCode                    116353 non-null  float64
#  34  Race                         117888 non-null  object
#  35  Ethnicity                    117888 non-null  object
#  36  UTILITIES_PROCEED            35323 non-null   float64
#  37  PAYROLL_PROCEED              117744 non-null  float64
#  38  MORTGAGE_INTEREST_PROCEED    1694 non-null    float64
#  39  RENT_PROCEED                 3862 non-null    float64
#  40  REFINANCE_EIDL_PROCEED       7035 non-null    float64
#  41  HEALTH_CARE_PROCEED          1485 non-null    float64
#  42  DEBT_INTEREST_PROCEED        908 non-null     float64
#  43  BusinessType                 117862 non-null  object
#  44  OriginatingLenderLocationID  117888 non-null  int64
#  45  OriginatingLender            117888 non-null  object
#  46  OriginatingLenderCity        117888 non-null  object
#  47  OriginatingLenderState       117888 non-null  object
#  48  Gender                       117888 non-null  object
#  49  Veteran                      117888 non-null  object
#  50  NonProfit                    3515 non-null    object
#  51  ForgivenessAmount            112324 non-null  float64
#  52  ForgivenessDate              112324 non-null  object
# dtypes: float64(12), int64(7), object(34)
# memory usage: 47.7+ MB

# %% [markdown]
# **Talk to your partner:** which of these missing columns would actually matter for a business question?
# Is a missing `JobsReported` the same kind of problem as a missing `NAICSCode`?

# %% [markdown]
# ## 3 · Are there duplicates?
#
# Real datasets often have near-duplicate rows. `LoanNumber` should be unique — is it?

# %%
# YOUR CODE HERE 🛠️  (we build this together in studio)\n
df.nunique()
# Out:
# LoanNumber                     117888
# DateApproved                      236
# SBAOfficeCode                       8
# ProcessingMethod                    2
# BorrowerName                   100496
# BorrowerAddress                 99288
# BorrowerCity                     1114
# BorrowerState                       1
# BorrowerZip                     46707
# LoanStatusDate                    764
# LoanStatus                          3
# Term                               82
# SBAGuarantyPercentage               1
# InitialApprovalAmount           52445
# CurrentApprovalAmount           52622
# UndisbursedAmount                   1
# FranchiseName                     379
# ServicingLenderLocationID         571
# ServicingLenderName               567
# ServicingLenderAddress            568
# ServicingLenderCity               448
# ServicingLenderState               50
# ServicingLenderZip                561
# RuralUrbanIndicator                 2
# HubzoneIndicator                    2
# LMIIndicator                        2
# BusinessAgeDescription              5
# ProjectCity                      1120
# ProjectCountyName                  22
# ProjectState                        5
# ProjectZip                      46900
# CD                                 23
# JobsReported                      376
# NAICSCode                        1032
# Race                                7
# Ethnicity                           3
# UTILITIES_PROCEED                3086
# PAYROLL_PROCEED                 58922
# MORTGAGE_INTEREST_PROCEED         948
# RENT_PROCEED                     2535
# REFINANCE_EIDL_PROCEED             81
# HEALTH_CARE_PROCEED               833
# DEBT_INTEREST_PROCEED             217
# BusinessType                       20
# OriginatingLenderLocationID       618
# OriginatingLender                 586
# OriginatingLenderCity             480
# OriginatingLenderState             50
# Gender                              3
# Veteran                             4
# NonProfit                           1
# ForgivenessAmount              104438
# ForgivenessDate                   667
# dtype: int64

# %% [markdown]
# ## 4 · Describe the money
#
# `describe()` on the loan amounts. Then find the outliers and argue about them —
# are they errors, or just the biggest employers in the state?

# %%
df['InitialApprovalAmount'].describe()
# Out:
# count    1.178880e+05
# mean     8.425945e+04
# std      2.764603e+05
# min      0.000000e+00
# 25%      1.067375e+04
# 50%      2.083300e+04
# 75%      5.930000e+04
# max      1.000000e+07
# Name: InitialApprovalAmount, dtype: float64

# %%
df['InitialApprovalAmount'].hist()
# Out:
# <Axes: >

# %%
import numpy as np
np.log(df['InitialApprovalAmount']).hist()
# Out:
# /usr/local/lib/python3.13/dist-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1203/2000428087.py in <cell line: 0>()
#       1 import numpy as np
# ----> 2 np.log(df['InitialApprovalAmount']).hist()
#
# /usr/local/lib/python3.13/dist-packages/pandas/plotting/_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, legend, **kwargs)
#     127     """
#     128     plot_backend = _get_plot_backend(backend)
# --> 129     return plot_backend.hist_series(
#     130         self,
#     131         by=by,
#
# /usr/local/lib/python3.13/dist-packages/pandas/plotting/_matplotlib/hist.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, legend, **kwds)
#     452         if legend:
#     453             kwds["label"] = self.name
# --> 454         ax.hist(values, bins=bins, **kwds)
#     455         if legend:
#     456             ax.legend()
#
# /usr/local/lib/python3.13/dist-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     451                 "parameter will become keyword-only in %(removal)s.",
#     452                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453         return func(*args, **kwargs)
#     454
#     455     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# /usr/local/lib/python3.13/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1519     def inner(ax, *args, data=None, **kwargs):
#    1520         if data is None:
# -> 1521             return func(
#    1522                 ax,
#    1523                 *map(cbook.sanitize_sequence, args),
#
# /usr/local/lib/python3.13/dist-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    7091             # this will automatically overwrite bins,
#    7092             # so that each histogram uses the same bins
# -> 7093             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    7094             tops.append(m)
#    7095         tops = np.array(tops, float)  # causes problems later if it's an int
#
# /usr/local/lib/python3.13/dist-packages/numpy/lib/_histograms_impl.py in histogram(a, bins, range, density, weights)
#     795     a, weights = _ravel_and_check_weights(a, weights)
#     796
# --> 797     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     798
#     799     # Histogram is an integer or a float array depending on the weights.
#
# /usr/local/lib/python3.13/dist-packages/numpy/lib/_histograms_impl.py in _get_bin_edges(a, bins, range, weights)
#     428             raise ValueError('`bins` must be positive, when an integer')
#     429
# --> 430         first_edge, last_edge = _get_outer_edges(a, range)
#     431
#     432     elif np.ndim(bins) == 1:
#
# /usr/local/lib/python3.13/dist-packages/numpy/lib/_histograms_impl.py in _get_outer_edges(a, range)
#     313                 'max must be larger than min in range parameter.')
#     314         if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# --> 315             raise ValueError(
#     316                 "supplied range of [{}, {}] is not finite".format(first_edge, last_edge))
#     317     elif a.size == 0:
#
# ValueError: supplied range of [-inf, 16.11809565095832] is not finite

# %%
#Using AI

import numpy as np

df['2digNAICS'] = df['NAICSCode']
#extract the initial 2 digit of NAICS Code

#group by 2 digit NAICS code and calcuate the mean of the sum of NAICS model
# Out:
# 0    812930.0
# 1    561311.0
# 2    322230.0
# 3    561720.0
# 4    541110.0
# 5    325510.0
# 6    541110.0
# 7    621111.0
# 8    238150.0
# 9    541211.0
# Name: NAICSCode, dtype: float64

# %% [markdown]
# **Mean vs median time** (this is your Math Check muscle): compute both for `InitialApprovalAmount`.
# Which is bigger, and what does that gap tell you about who got PPP money?

# %%
# YOUR CODE HERE 🛠️  (we build this together in studio)\n

# %% [markdown]
# ## 5 · Which industries got the money?
#
# `NAICSCode` is a 6-digit industry code — the first 2 digits give the sector. Watch how many rows we lose to missing codes.

# %%
# YOUR CODE HERE 🛠️  (we build this together in studio)\n

# %% [markdown]
# ## 6 · Where in Connecticut?
#
# Top cities by loan count — and watch for the data dirt (same city spelled multiple ways?).

# %%
# YOUR CODE HERE 🛠️  (we build this together in studio)\n

# %% [markdown]
# ## 7 · The dollars-per-job question
#
# PPP was meant to protect paychecks. So: **dollars per job reported**. What do you find at the extremes —
# and do you believe the `JobsReported` column?

# %%
# YOUR CODE HERE 🛠️  (we build this together in studio)\n

# %%
# YOUR CODE HERE 🛠️  (we build this together in studio)\n

# %% [markdown]
# ## 8 · Your three findings 📝
#
# With your partner, write **three findings** below. Each one = **one plot or one table + two sentences**
# (what you see, and why a decision-maker should care). This is the exact shape Assignment 1 grades.
#
# Then: File → **Save a copy in GitHub** → your `opim5641-work` repo.

# %% [markdown]
# ### Finding 1
#
# *(your plot/table + two sentences)*

# %%
# YOUR CODE HERE 🛠️  (we build this together in studio)\n

# %% [markdown]
# ### Finding 2

# %%
# YOUR CODE HERE 🛠️  (we build this together in studio)\n

# %% [markdown]
# ### Finding 3

# %%
# YOUR CODE HERE 🛠️  (we build this together in studio)\n
